# %% [markdown]
# # TF-IDF with Scikit-Learn

# %% [markdown]
# In our last lab, we started using python for text analysis. Now we will try a text analysis method called *term frequency–inverse document frequency*, often abbreviated *tf-idf*. Tf-idf is a method that tries to identify the most distinctively frequent or significant words in a document.
#
# In this lesson, we're going to learn how to calculate tf-idf scores using a collection of plain text (.txt) files and the Python library scikit-learn, which has a quick and nifty module called [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# In this lesson, we will cover how to:
# - Calculate and normalize tf-idf scores for U.S. Inaugural Addresses with scikit-learn

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### U.S. Inaugural Addresses
#
# <blockquote class="epigraph" style=" padding: 10px">
#
# This is the meaning of our liberty and our creed; why men and women and children of every race and every faith can join in celebration across this magnificent Mall, and why a man whose father less than 60 years ago might not have been served at a local restaurant can now stand before you to take a most sacred oath.  So let us mark this day with remembrance of who we are and how far we have traveled.
# <p class ="attribution">—Barack Obama, Inaugural Presidential Address, January 2009
#     </p>
#
# </blockquote>

# %% [markdown]
# During Barack Obama's Inaugural Address in January 2009, he mentioned "women" four different times, including in the passage quoted above. How distinctive is Obama's inclusion of women in this address compared to all other U.S. Presidents? This is one of the questions that we're going to try to answer with tf-idf.

# %% [markdown]
# ## Breaking Down the TF-IDF Formula

# %% [markdown]
# But first, let's quickly discuss the tf-idf formula. The idea is pretty simple.

# %% [markdown]
# **tf-idf = term_frequency * inverse_document_frequency**

# %% [markdown]
# **term_frequency** = number of times a given term appears in document

# %% [markdown]
# **inverse_document_frequency** = log(total number of documents / number of documents with term) + 1**\***

# %% [markdown]
# You take the number of times a term occurs in a document (term frequency). Then you take the number of documents in which the same term occurs at least once divided by the total number of documents (document frequency), and you flip that fraction on its head (inverse document frequency). Then you multiply the two numbers together (term_frequency * inverse_document_frequency).
#
# The reason we take the *inverse*, or flipped fraction, of document frequency is to boost the rarer words that occur in relatively few documents. Think about the inverse document frequency for the word "said" vs the word "pigeon." The term "said" appears in 13 (document frequency) of 14 (total documents) *Lost in the City* stories (14 / 13 --> a smaller inverse document frequency) while the term "pigeons" only occurs in 2 (document frequency) of the 14 stories (total documents) (14 / 2 --> a bigger inverse document frequency, a bigger tf-idf boost).

# %% [markdown]
# *There are a bunch of slightly different ways that you can calculate inverse document frequency. The version of idf that we're going to use is the [scikit-learn default](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer), which uses "smoothing" aka it adds a "1" to the numerator and denominator:

# %% [markdown]
# **inverse_document_frequency**  = log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %% [markdown]
# <div class="margin sidebar" style=" padding: 10px">
#
# > If smooth_idf=True (the default), the constant “1” is added to the numerator and denominator of the idf as if an extra document was seen containing every term in the collection exactly once, which prevents zero divisions: idf(t) = log [ (1 + n) / (1 + df(t)) ] + 1.
# > -[scikit-learn documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer)
#
# </div>

# %% [markdown]
# ## TF-IDF with scikit-learn

# %% [markdown]
# [scikit-learn](https://scikit-learn.org/stable/index.html), imported as `sklearn`, is a popular Python library for machine learning approaches such as clustering, classification, and regression. Though we're not doing any machine learning in this lesson, we're nevertheless going to use scikit-learn's `TfidfVectorizer` and `CountVectorizer`.

# %% [markdown]
# Install scikit-learn

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post11.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# Import necessary modules and libraries

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
pd.set_option("max_rows", 600)


from pathlib import Path
import glob

# %% [markdown]
# <div class="admonition pandasreview" name="html-admonition" style="background: black; color: white; padding: 10px">
# <p class="title">Pandas</p>
#  Do you need a refresher or introduction to the Python data analysis library Pandas? Be sure to check out <a href="https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Analysis/Pandas-Basics-Part1.html"> Pandas Basics (1-3) </a> in this textbook!
#
# </div>

# %% [markdown]
# We're also going to import `pandas` and change its default display setting. And we're going to import two libraries that will help us work with files and the file system: [`pathlib`](https://docs.python.org/3/library/pathlib.html##basic-use) and [`glob`](https://docs.python.org/3/library/glob.html).

# %% [markdown]
# #### Set Directory Path

# %% [markdown]
# Below we're setting the directory filepath that contains all the text files that we want to analyze.

# %%
directory_path = "../texts/history/US_Inaugural_Addresses/"

# %% [markdown]
# Then we're going to use `glob` and `Path` to make a list of all the filepaths in that directory and a list of all the short story titles.

# %%
text_files = glob.glob(f"{directory_path}/*.txt")

# %%
text_files
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/35_coolidge_1925.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/54_bush_george_w_2001.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/40_roosevelt_franklin_1945.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/18_buchanan_1857.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/29_mckinley_1901.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/12_jackson_1833.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/36_hoover_1929.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/25_cleveland_1885.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/45_johnson_1965.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/38_roosevelt_franklin_1937.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/28_mckinley_1897.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/14_harrison_1841.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/19_lincoln_1861.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/26_harrison_1889.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/13_van_buren_1837.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/01_washington_1789.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/17_pierce_1853.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/16_taylor_1849.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/24_garfield_1881.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/15_polk_1845.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/32_wilson_1913.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/31_taft_1909.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/07_madison_1813.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/27_cleveland_1893.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/11_jackson_1829.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/33_wilson_1917.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/03_adams_john_1797.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/34_harding_1921.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/48_carter_1977.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/06_madison_1809.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/23_hayes_1877.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/08_monroe_1817.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/10_adams_john_quincy_1825.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/05_jefferson_1805.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/04_jefferson_1801.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/21_grant_1869.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/09_monroe_1821.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/30_roosevelt_theodore_1905.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/52_clinton_1993.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/46_nixon_1969.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/39_roosevelt_franklin_1941.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/22_grant_1873.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/44_kennedy_1961.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/42_eisenhower_1953.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/51_bush_george_h_w_1989.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/49_reagan_1981.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/57_obama_2013.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/02_washington_1793.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/55_bush_george_w_2005.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/53_clinton_1997.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/56_obama_2009.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/43_eisenhower_1957.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/47_nixon_1973.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/20_lincoln_1865.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/41_truman_1949.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/50_reagan_1985.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/58_trump_2017.txt',
#  '/content/drive/MyDrive/Colab Notebooks/US_Inaugural_Addresses/37_roosevelt_franklin_1933.txt']

# %%
text_titles = [Path(text).stem for text in text_files]

# %%
text_titles
# Out:
# ['35_coolidge_1925',
#  '54_bush_george_w_2001',
#  '40_roosevelt_franklin_1945',
#  '18_buchanan_1857',
#  '29_mckinley_1901',
#  '12_jackson_1833',
#  '36_hoover_1929',
#  '25_cleveland_1885',
#  '45_johnson_1965',
#  '38_roosevelt_franklin_1937',
#  '28_mckinley_1897',
#  '14_harrison_1841',
#  '19_lincoln_1861',
#  '26_harrison_1889',
#  '13_van_buren_1837',
#  '01_washington_1789',
#  '17_pierce_1853',
#  '16_taylor_1849',
#  '24_garfield_1881',
#  '15_polk_1845',
#  '32_wilson_1913',
#  '31_taft_1909',
#  '07_madison_1813',
#  '27_cleveland_1893',
#  '11_jackson_1829',
#  '33_wilson_1917',
#  '03_adams_john_1797',
#  '34_harding_1921',
#  '48_carter_1977',
#  '06_madison_1809',
#  '23_hayes_1877',
#  '08_monroe_1817',
#  '10_adams_john_quincy_1825',
#  '05_jefferson_1805',
#  '04_jefferson_1801',
#  '21_grant_1869',
#  '09_monroe_1821',
#  '30_roosevelt_theodore_1905',
#  '52_clinton_1993',
#  '46_nixon_1969',
#  '39_roosevelt_franklin_1941',
#  '22_grant_1873',
#  '44_kennedy_1961',
#  '42_eisenhower_1953',
#  '51_bush_george_h_w_1989',
#  '49_reagan_1981',
#  '57_obama_2013',
#  '02_washington_1793',
#  '55_bush_george_w_2005',
#  '53_clinton_1997',
#  '56_obama_2009',
#  '43_eisenhower_1957',
#  '47_nixon_1973',
#  '20_lincoln_1865',
#  '41_truman_1949',
#  '50_reagan_1985',
#  '58_trump_2017',
#  '37_roosevelt_franklin_1933']

# %% [markdown]
# ## Calculate tf–idf

# %% [markdown]
# To calculate tf–idf scores for every word, we're going to use scikit-learn's [`TfidfVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# When you initialize TfidfVectorizer, you can choose to set it with different parameters. These parameters will change the way you calculate tf–idf.

# %% [markdown]
# The recommended way to run `TfidfVectorizer` is with smoothing (`smooth_idf = True`) and normalization (`norm='l2'`) turned on. These parameters will better account for differences in text length, and overall produce more meaningful tf–idf scores. Smoothing and L2 normalization are actually the default settings for `TfidfVectorizer`, so to turn them on, you don't need to include any extra code at all.

# %% [markdown]
# Initialize TfidfVectorizer with desired parameters (default smoothing and normalization)

# %%
tfidf_vectorizer = TfidfVectorizer(input='filename', stop_words='english')

# %% [markdown]
# Run TfidfVectorizer on our `text_files`

# %%
tfidf_vector = tfidf_vectorizer.fit_transform(text_files)

# %% [markdown]
# Make a DataFrame out of the resulting tf–idf vector, setting the "feature names" or words as columns and the titles as rows

# %%
#tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=text_titles, columns=tfidf_vectorizer.get_feature_names())
tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=text_titles, columns=tfidf_vectorizer.get_feature_names_out())

# %% [markdown]
# Add column for document frequency aka number of times word appears in all documents

# %%
tfidf_df.loc['00_Document Frequency'] = (tfidf_df > 0).sum()

# %%
tfidf_slice = tfidf_df[['government', 'borders', 'people', 'obama', 'war', 'honor','foreign', 'men', 'women', 'children']]
tfidf_slice.sort_index().round(decimals=2)
# Out:
#                             government  borders  people  obama    war  honor  \
# 00_Document Frequency            53.00     5.00   56.00   3.00  45.00  32.00
# 01_washington_1789                0.11     0.00    0.05   0.00   0.00   0.00
# 02_washington_1793                0.06     0.00    0.05   0.00   0.00   0.08
# 35_coolidge_1925               0.02   0.02   0.02      0.00
# 36_hoover_1929                 0.01   0.03   0.03      0.01
# 37_roosevelt_franklin_1933     0.03   0.02   0.00      0.00
# 38_roosevelt_franklin_1937     0.00   0.10   0.07      0.02
# 39_roosevelt_franklin_1941     0.00   0.07   0.03      0.00
# 40_roosevelt_franklin_1945     0.00   0.10   0.05      0.04
# 41_truman_1949                 0.01   0.06   0.00      0.00
# 42_eisenhower_1953             0.00   0.07   0.00      0.00
# 43_eisenhower_1957             0.00   0.07   0.00      0.00
# 44_kennedy_1961                0.00   0.01   0.00      0.00
# 45_johnson_1965                0.02   0.03   0.00      0.05
# 46_nixon_1969                  0.00   0.01   0.00      0.00
# 47_nixon_1973                  0.00   0.00   0.00      0.02
# 48_carter_1977                 0.02   0.00   0.00      0.00
# 49_reagan_1981                 0.00   0.02   0.04      0.09
# 50_reagan_1985                 0.00   0.03   0.04      0.00
# 51_bush_george_h_w_1989        0.01   0.04   0.06      0.07
# 52_clinton_1993                0.02   0.01   0.02      0.06
# 53_clinton_1997                0.00   0.00   0.02      0.10
# 54_bush_george_w_2001          0.00   0.00   0.00      0.08
# 55_bush_george_w_2005          0.00   0.02   0.04      0.00
# 56_obama_2009                  0.00   0.04   0.08      0.05
# 57_obama_2013                  0.00   0.04   0.04      0.06
# 58_trump_2017                  0.05   0.03   0.05      0.04

# %% [markdown]
# Let's drop "OO_Document Frequency" since we were just using it for illustration purposes.

# %%
tfidf_df = tfidf_df.drop('00_Document Frequency', errors='ignore')

# %% [markdown]
# Let's reorganize the DataFrame so that the words are in rows rather than columns.

# %%
tfidf_df.stack().reset_index()
# Out:
#                            level_0    level_1    0
# 0                 35_coolidge_1925        000  0.0
# 1                 35_coolidge_1925         03  0.0
# 2                 35_coolidge_1925         04  0.0
# 3                 35_coolidge_1925         05  0.0
# 4                 35_coolidge_1925        100  0.0
# ...                            ...        ...  ...
# 521937  37_roosevelt_franklin_1933    zachary  0.0
# 521938  37_roosevelt_franklin_1933       zeal  0.0
# 521939  37_roosevelt_franklin_1933    zealous  0.0
# 521940  37_roosevelt_franklin_1933  zealously  0.0
# 521941  37_roosevelt_franklin_1933       zone  0.0
#
# [521942 rows x 3 columns]

# %%
tfidf_df = tfidf_df.stack().reset_index()

# %%
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'document','level_1': 'term', 'level_2': 'term'})

# %% [markdown]
# To find out the top 10 words with the highest tf–idf for every story, we're going to sort by document and tfidf score and then groupby document and take the first 10 values.

# %%
tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(10)
# Out:
#                           document            term     tfidf
# 138692          01_washington_1789      government  0.113681
# 139093          01_washington_1789       immutable  0.103883
# 139160          01_washington_1789     impressions  0.103883
# 141322          01_washington_1789    providential  0.103883
# 140616          01_washington_1789           ought  0.103728
# 141336          01_washington_1789          public  0.103102
# 141102          01_washington_1789         present  0.097516
# 141374          01_washington_1789  qualifications  0.096372
# 140796          01_washington_1789      peculiarly  0.090546
# 39082             29_mckinley_1901       executive  0.147843
# 40350             29_mckinley_1901     inhabitants  0.147374
# 37686             29_mckinley_1901        congress  0.141999
# 41819             29_mckinley_1901          people  0.116839
# 43623             29_mckinley_1901          states  0.102186
# 44468             29_mckinley_1901          united  0.100439
# 42095             29_mckinley_1901     preparation  0.097925
# 339591  30_roosevelt_theodore_1905         regards  0.199163
# 339158  30_roosevelt_theodore_1905        problems  0.182463
# 340939  30_roosevelt_theodore_1905           tasks  0.150068
# 333581  30_roosevelt_theodore_1905          aright  0.146306
# 339746  30_roosevelt_theodore_1905        republic  0.121428
# 337809  30_roosevelt_theodore_1905            life  0.118701
# 334211  30_roosevelt_theodore_1905           cause  0.116483
# 336180  30_roosevelt_theodore_1905           faced  0.115730
# 334600  30_roosevelt_theodore_1905      conditions  0.115373
# 341858  30_roosevelt_theodore_1905            wish  0.106771
# 193480                31_taft_1909      interstate  0.206957
# 190133                31_taft_1909        business  0.201378
# 196949                31_taft_1909          tariff  0.154802
# 194379                31_taft_1909           negro  0.153669
# 196478                31_taft_1909           south  0.129384
# 192686                31_taft_1909      government  0.121451
# 195265                31_taft_1909          proper  0.114684
# 195390                31_taft_1909            race  0.113413
# 192301                31_taft_1909         feeling  0.111255
# 190165                31_taft_1909           canal  0.110879
# 183721              32_wilson_1913           great  0.158659
# 185111              32_wilson_1913             men  0.142924
# 183247              32_wilson_1913        familiar  0.141669
# 187653              32_wilson_1913         stirred  0.141669
# 187720              32_wilson_1913         studied  0.141669
# 188057              32_wilson_1913          things  0.123915
# 184646              32_wilson_1913         justice  0.105759
# 183687              32_wilson_1913      government  0.105520
# 184826              32_wilson_1913            life  0.102168
# 184903              32_wilson_1913            look  0.100095
# 233871              33_wilson_1917          wished  0.228593
# 226879              33_wilson_1917         counsel  0.174639
# 231346              33_wilson_1917         purpose  0.152933
# 225210              33_wilson_1917          action  0.149960
# 232257              33_wilson_1917           shall  0.134404
# 233066              33_wilson_1917         thought  0.126568
# 232584              33_wilson_1917           stand  0.121313
# 232234              33_wilson_1917             set  0.111215
# 230967              33_wilson_1917        politics  0.108510
# 227612              33_wilson_1917           drawn  0.104783
# 251911             34_harding_1921           world  0.196268
# 244352             34_harding_1921    civilization  0.157095
# 243434             34_harding_1921         america  0.155684
# 251738             34_harding_1921             war  0.120631
# 249645             34_harding_1921    relationship  0.118846
# 249756             34_harding_1921        republic  0.117160
# 248578             34_harding_1921           order  0.110128
# 251362             34_harding_1921   understanding  0.109915
# 248386             34_harding_1921             new  0.097567
# 243442             34_harding_1921            amid  0.095077
# 1918              35_coolidge_1925         country  0.120814
# 5631              35_coolidge_1925           ought  0.116721
# 6779              35_coolidge_1925      represents  0.114495
# 7979              35_coolidge_1925             tax  0.112826
# 3741              35_coolidge_1925           great  0.109908
# 6288              35_coolidge_1925        property  0.108285
# 5757              35_coolidge_1925           party  0.107300
# 7614              35_coolidge_1925          stands  0.107257
# 5801              35_coolidge_1925           peace  0.104170
# 5823              35_coolidge_1925          people  0.101306
# 61836               36_hoover_1929             sup  0.296865
# 440278       55_bush_george_w_2005         tyranny  0.127272
# 439154       55_bush_george_w_2005            seen  0.110386
# 437305       55_bush_george_w_2005          nation  0.096199
# 433200       55_bush_george_w_2005           cause  0.092545
# 435917       55_bush_george_w_2005         history  0.092422
# 433132       55_bush_george_w_2005            came  0.091988
# 450411               56_obama_2009         america  0.148351
# 455303               56_obama_2009          nation  0.120229
# 455363               56_obama_2009             new  0.118002
# 458098               56_obama_2009           today  0.114792
# 453595               56_obama_2009      generation  0.100654
# 454767               56_obama_2009             let  0.091100
# 454583               56_obama_2009            jobs  0.090727
# 451916               56_obama_2009          crisis  0.087235
# 453784               56_obama_2009            hard  0.084859
# 458866               56_obama_2009           women  0.084859
# 418595               57_obama_2013         journey  0.167591
# 415909               57_obama_2013           creed  0.139659
# 417599               57_obama_2013      generation  0.127260
# 414415               57_obama_2013         america  0.125044
# 415519               57_obama_2013        complete  0.114891
# 420751               57_obama_2013        requires  0.114891
# 419777               57_obama_2013          people  0.110351
# 422088               57_obama_2013            time  0.105563
# 422102               57_obama_2013           today  0.103668
# 416980               57_obama_2013         evident  0.100896
# 504405               58_trump_2017         america  0.350162
# 506586               58_trump_2017          dreams  0.156436
# 504406               58_trump_2017        american  0.149226
# 508577               58_trump_2017            jobs  0.142766
# 510263               58_trump_2017       protected  0.132439
# 509410               58_trump_2017           obama  0.120288
# 509767               58_trump_2017          people  0.112370
# 512002               58_trump_2017           thank  0.109171
# 504990               58_trump_2017         borders  0.107075
# 512597               58_trump_2017              ve  0.107075

# %%
top_tfidf = tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(10)

# %% [markdown]
# We can zoom in on particular words and particular documents.

# %%
top_tfidf[top_tfidf['term'].str.contains('women')]
# Out:
#              document   term     tfidf
# 458866  56_obama_2009  women  0.084859

# %% [markdown]
# It turns out that the term "women" is very distinctive in Obama's Inaugural Address.

# %%
top_tfidf[top_tfidf['document'].str.contains('obama')]
# Out:
#              document        term     tfidf
# 450411  56_obama_2009     america  0.148351
# 455303  56_obama_2009      nation  0.120229
# 455363  56_obama_2009         new  0.118002
# 458098  56_obama_2009       today  0.114792
# 453595  56_obama_2009  generation  0.100654
# 454767  56_obama_2009         let  0.091100
# 454583  56_obama_2009        jobs  0.090727
# 451916  56_obama_2009      crisis  0.087235
# 453784  56_obama_2009        hard  0.084859
# 458866  56_obama_2009       women  0.084859
# 418595  57_obama_2013     journey  0.167591
# 415909  57_obama_2013       creed  0.139659
# 417599  57_obama_2013  generation  0.127260
# 414415  57_obama_2013     america  0.125044
# 415519  57_obama_2013    complete  0.114891
# 420751  57_obama_2013    requires  0.114891
# 419777  57_obama_2013      people  0.110351
# 422088  57_obama_2013        time  0.105563
# 422102  57_obama_2013       today  0.103668
# 416980  57_obama_2013     evident  0.100896

# %%
top_tfidf[top_tfidf['document'].str.contains('trump')]
# Out:
#              document       term     tfidf
# 504405  58_trump_2017    america  0.350162
# 506586  58_trump_2017     dreams  0.156436
# 504406  58_trump_2017   american  0.149226
# 508577  58_trump_2017       jobs  0.142766
# 510263  58_trump_2017  protected  0.132439
# 509410  58_trump_2017      obama  0.120288
# 509767  58_trump_2017     people  0.112370
# 512002  58_trump_2017      thank  0.109171
# 504990  58_trump_2017    borders  0.107075
# 512597  58_trump_2017         ve  0.107075

# %%
top_tfidf[top_tfidf['document'].str.contains('kennedy')]
# Out:
#                document     term     tfidf
# 382775  44_kennedy_1961      let  0.267869
# 385307  44_kennedy_1961    sides  0.262849
# 383922  44_kennedy_1961   pledge  0.160960
# 378633  44_kennedy_1961      ask  0.107713
# 378865  44_kennedy_1961    begin  0.106495
# 379992  44_kennedy_1961     dare  0.106495
# 386896  44_kennedy_1961    world  0.103110
# 381314  44_kennedy_1961    final  0.102311
# 383371  44_kennedy_1961      new  0.096600
# 381121  44_kennedy_1961  explore  0.094223

# %% [markdown]
# ## Visualize TF-IDF

# %% [markdown]
# We can also visualize our TF-IDF results with the data visualization library Altair.

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (4.2.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair) (4.19.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from altair) (1.23.5)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from altair) (1.5.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair) (0.12.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)

# %% [markdown]
# Let's make a heatmap that shows the highest TF-IDF scoring words for each president, and let's put a red dot next to two terms of interest: "war" and "peace":
#
# The code below was contributed by [Eric Monson](https://github.com/emonson). Thanks, Eric!

# %%
import altair as alt
import numpy as np

# Terms in this list will get a red dot in the visualization
term_list = ['war', 'peace']

# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_tfidf.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_tfidf.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'document:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["document"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# red circle over terms in above list
circle = base.mark_circle(size=100).encode(
    color = alt.condition(
        alt.FieldOneOfPredicate(field='term', oneOf=term_list),
        alt.value('red'),
        alt.value('#FFFFFF00')
    )
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + circle + text).properties(width = 600)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Take a few minutes to explore the dataframe below and then answer the following questions.

# %% [markdown]
# **1.** What is the difference between a tf-idf score and raw word frequency?

# %% [markdown]
# **Your answer here**

# %% [markdown]
# **2.** Based on the dataframe above, what is one potential problem or limitation that you notice with tf-idf scores?

# %% [markdown]
# **Your answer here**

# %% [markdown]
# **3.** What's another collection of texts that you think might be interesting to analyze with tf-idf scores?  Why?

# %% [markdown]
# **Your answer here**
